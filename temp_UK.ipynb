# %%
import pandas as pd

roads = pd.read_csv("dft-road-casualty-statistics-collision-last-5-years.csv")

print(roads.shape)
display(roads.head())
print(roads.columns.tolist())
# Out:
# C:\Users\Hi\AppData\Local\Temp\ipykernel_11960\3495979206.py:3: DtypeWarning: Columns (0,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   roads = pd.read_csv("dft-road-casualty-statistics-collision-last-5-years.csv")
# (513801, 44)
#   collision_index  collision_year collision_ref_no  location_easting_osgr  \
# 0   202517M102225            2025        17M102225               449804.0
# 1   202417S111924            2024        17S111924               444670.0
# 2   2025111687011            2025        111687011               427772.0
# 3   2025070326701            2025        070326701               351585.0
# 4   2025070353559            2025        070353559               351101.0
#
#    location_northing_osgr  longitude  latitude  police_force  \
# 0                519612.0   -1.23119  54.56929            17
# 1                520502.0   -1.31046  54.57776            17
# 2                515144.0   -1.57237  54.53082            11
# 3                382993.0   -2.72862  53.34161             7
# 4                382954.0   -2.73589  53.34121             7
#
#    collision_severity  number_of_vehicles  ...  carriageway_hazards_historic  \
# 0                   3                   1  ...                            -1
# 1                   2                   1  ...                            -1
# 2                   3                   2  ...                            -1
# 3                   1                   1  ...                            -1
# 4                   3                   2  ...                            -1
#
#   carriageway_hazards  urban_or_rural_area  \
# 0                   0                    1
# 1                   0                    1
# 2                   0                    1
# 3                   0                    1
# 4                   0                    1
#
#   did_police_officer_attend_scene_of_accident  trunk_road_flag  \
# 0                                           1                2
# 1                                           1                2
# 2                                           3                2
# 3                                           1                2
# 4                                           2                2
#
#   lsoa_of_accident_location enhanced_severity_collision  \
# 0                 E01012092                           3
# 1                 E01012194                           7
# 2                 E01035185                           3
# 3                 E01012430                           1
# 4                 E01012431                           3
#
#   collision_injury_based  collision_adjusted_severity_serious  \
# 0                      1                                  0.0
# 1                      1                                  1.0
# 2                      1                                  0.0
# 3                      1                                  0.0
# 4                      1                                  0.0
#
#    collision_adjusted_severity_slight
# 0                                 1.0
# 1                                 0.0
# 2                                 1.0
# 3                                 0.0
# 4                                 1.0
#
# [5 rows x 44 columns]
# ['collision_index', 'collision_year', 'collision_ref_no', 'location_easting_osgr', 'location_northing_osgr', 'longitude', 'latitude', 'police_force', 'collision_severity', 'number_of_vehicles', 'number_of_casualties', 'date', 'day_of_week', 'time', 'local_authority_district', 'local_authority_ons_district', 'local_authority_highway', 'local_authority_highway_current', 'first_road_class', 'first_road_number', 'road_type', 'speed_limit', 'junction_detail_historic', 'junction_detail', 'junction_control', 'second_road_class', 'second_road_number', 'pedestrian_crossing_human_control_historic', 'pedestrian_crossing_physical_facilities_historic', 'pedestrian_crossing', 'light_conditions', 'weather_conditions', 'road_surface_conditions', 'special_conditions_at_site', 'carriageway_hazards_historic', 'carriageway_hazards', 'urban_or_rural_area', 'did_police_officer_attend_scene_of_accident', 'trunk_road_flag', 'lsoa_of_accident_location', 'enhanced_severity_collision', 'collision_injury_based', 'collision_adjusted_severity_serious', 'collision_adjusted_severity_slight']

# %%
roads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513801 entries, 0 to 513800
# Data columns (total 44 columns):
#  #   Column                                            Non-Null Count   Dtype
# ---  ------                                            --------------   -----
#  0   collision_index                                   513801 non-null  object
#  1   collision_year                                    513801 non-null  int64
#  2   collision_ref_no                                  513801 non-null  object
#  3   location_easting_osgr                             513748 non-null  float64
#  4   location_northing_osgr                            513748 non-null  float64
#  5   longitude                                         513748 non-null  float64
#  6   latitude                                          513748 non-null  float64
#  7   police_force                                      513801 non-null  int64
#  8   collision_severity                                513801 non-null  int64
#  9   number_of_vehicles                                513801 non-null  int64
#  10  number_of_casualties                              513801 non-null  int64
#  11  date                                              513801 non-null  object
#  12  day_of_week                                       513801 non-null  int64
#  13  time                                              513801 non-null  object
#  14  local_authority_district                          513801 non-null  int64
#  15  local_authority_ons_district                      513801 non-null  object
#  16  local_authority_highway                           513801 non-null  object
#  17  local_authority_highway_current                   513801 non-null  object
#  18  first_road_class                                  513801 non-null  int64
#  19  first_road_number                                 513801 non-null  int64
#  20  road_type                                         513801 non-null  int64
#  21  speed_limit                                       513801 non-null  int64
#  22  junction_detail_historic                          513801 non-null  int64
#  23  junction_detail                                   513801 non-null  int64
#  24  junction_control                                  513801 non-null  int64
#  25  second_road_class                                 513801 non-null  int64
#  26  second_road_number                                513801 non-null  int64
#  27  pedestrian_crossing_human_control_historic        513801 non-null  int64
#  28  pedestrian_crossing_physical_facilities_historic  513801 non-null  int64
#  29  pedestrian_crossing                               513801 non-null  int64
#  30  light_conditions                                  513801 non-null  int64
#  31  weather_conditions                                513801 non-null  int64
#  32  road_surface_conditions                           513801 non-null  int64
#  33  special_conditions_at_site                        513801 non-null  int64
#  34  carriageway_hazards_historic                      513801 non-null  int64
#  35  carriageway_hazards                               513801 non-null  int64
#  36  urban_or_rural_area                               513801 non-null  int64
#  37  did_police_officer_attend_scene_of_accident       513801 non-null  int64
#  38  trunk_road_flag                                   513801 non-null  int64
#  39  lsoa_of_accident_location                         513801 non-null  object
#  40  enhanced_severity_collision                       513801 non-null  int64
#  41  collision_injury_based                            513801 non-null  int64
#  42  collision_adjusted_severity_serious               513801 non-null  float64
#  43  collision_adjusted_severity_slight                513801 non-null  float64
# dtypes: float64(6), int64(30), object(8)
# memory usage: 172.5+ MB

# %%
roads.isna().sum().sort_values(ascending=False).head(20)
# Out:
# location_easting_osgr                               53
# location_northing_osgr                              53
# longitude                                           53
# latitude                                            53
# collision_index                                      0
# carriageway_hazards_historic                         0
# second_road_number                                   0
# pedestrian_crossing_human_control_historic           0
# pedestrian_crossing_physical_facilities_historic     0
# pedestrian_crossing                                  0
# light_conditions                                     0
# weather_conditions                                   0
# road_surface_conditions                              0
# special_conditions_at_site                           0
# urban_or_rural_area                                  0
# carriageway_hazards                                  0
# junction_control                                     0
# did_police_officer_attend_scene_of_accident          0
# trunk_road_flag                                      0
# lsoa_of_accident_location                            0
# dtype: int64

# %%
roads.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# | Variable           | Likely type            | Useful? | Possible purpose     |
# | ------------------ | ---------------------- | ------- | -------------------- |
# | date               | temporal               | ✓       | trend/seasonality    |
# | time               | temporal               | ✓       | hour-of-day patterns |
# | collision_severity | ordinal/category       | ✓       | principal outcome    |
# | speed_limit        | numerical/ordinal-like | ✓       | road environment     |
# | weather_conditions | nominal                | ✓       | conditions           |
# | light_conditions   | nominal                | ✓       | conditions           |
# | longitude/latitude | spatial                | ✓       | mapping              |
# | number_of_casualties| numerical              | ✓       | collision impact     |
#
# collision_index', 'collision_year', 'collision_ref_no', 'location_easting_osgr', 'location_northing_osgr', 'longitude', 'latitude', 'police_force', 'collision_severity', 'number_of_vehicles', 'number_of_casualties', 'date', 'day_of_week', 'time', 'local_authority_district', 'local_authority_ons_district', 'local_authority_highway', 'local_authority_highway_current', 'first_road_class', 'first_road_number', 'road_type', 'speed_limit', 'junction_detail_historic', 'junction_detail', 'junction_control', 'second_road_class', 'second_road_number', 'pedestrian_crossing_human_control_historic', 'pedestrian_crossing_physical_facilities_historic', 'pedestrian_crossing', 'light_conditions', 'weather_conditions', 'road_surface_conditions', 'special_conditions_at_site', 'carriageway_hazards_historic', 'carriageway_hazards', 'urban_or_rural_area', 'did_police_officer_attend_scene_of_accident', 'trunk_road_flag', 'lsoa_of_accident_location', 'enhanced_severity_collision', 'collision_injury_based', 'collision_adjusted_severity_serious', 'collision_adjusted_severity_slight

# %%
roads["date"].head()
roads["collision_severity"].value_counts(dropna=False)
# Out:
# collision_severity
# 3    389435
# 2    116813
# 1      7553
# Name: count, dtype: int64
